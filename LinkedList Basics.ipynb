# %%
from typing import List

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:
        def df

# %%
from typing import List

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:
        def dfs(node, parent=None):
            stack.append((node, parent))

            while stack:
                node, parent = stack.pop()

                if not node:
                    continue

                node.parent = parent
                stack.append((node.left, node))
                stack.append((node.right, node))

        def find_nodes(node, distance):
            if not node:
                return

            if distance == k:
                result.append(node.val)

            if node.left is not node.parent:
                find_nodes(node.left, distance + 1)

            if node.right is not node.parent:
                find_nodes(node.right, distance + 1)

            if node.parent and node.parent is not node.left:
                find_nodes(node.parent.left, distance + 1)

            if node.parent and node.parent is not node.right:
                find_nodes(node.parent.right, distance + 1)

        stack = []
        result = []
        dfs(root)
        find_nodes(target, 0)
        return result

# Example usage:
# Create the tree
root = TreeNode(3)
root.left = TreeNode(5)
root.right = TreeNode(1)
root.left.left = TreeNode(6)
root.left.right = TreeNode(2)
root.right.left = TreeNode(0)
root.right.right = TreeNode(8)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

solution = Solution()
target_node = root.left  # Target node with value 5
k_distance = 2
result = solution.distanceK(root, target_node, k_distance)
print("Nodes at distance", k_distance, "from target:", result)  # Output: [7, 4, 1]
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[14], line 64
#      62 target_node = root.left  # Target node with value 5
#      63 k_distance = 2
# ---> 64 result = solution.distanceK(root, target_node, k_distance)
#      65 print("Nodes at distance", k_distance, "from target:", result)  # Output: [7, 4, 1]
#
# Cell In[14], line 46, in Solution.distanceK(self, root, target, k)
#      44 result = []
#      45 dfs(root)
# ---> 46 find_nodes(target, 0)
#      47 return result
#
# Cell In[14], line 32, in Solution.distanceK.<locals>.find_nodes(node, distance)
#      29     result.append(node.val)
#      31 if node.left is not node.parent:
# ---> 32     find_nodes(node.left, distance + 1)
#      34 if node.right is not node.parent:
#      35     find_nodes(node.right, distance + 1)
#
# Cell In[14], line 38, in Solution.distanceK.<locals>.find_nodes(node, distance)
# ...

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        dummy_head = ListNode(-1)
        current = dummy_head

        while list1 and list2:
            if list1.val <= list2.val:
                current.next = list1
                list1 = list1.next

            else: 
                current.next = list2
                list2 = list2.next

            current = current.next
        current.next = list1 if list1 else list2
        return dummy_head.next

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        dummy_head = ListNode(-1)
        current = dummy_head

        while list1 and list2:
            if list1.val <= list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next

            current = current.next

        # Add any remaining nodes from either list1 or list2
        current.next = list1 if list1 else list2

        return dummy_head.next

# %%
class Solution:
    def partitionString(self, s:str) -> int:
        seen_chars = set()
        partitions = 0

        for char in s:
            if char in seen_chars:
                seen_chars.clear()
                partitions += 1
            seen_chars.add(char)
        return paritions + 1

# %%
class Solution:
    def partitionString(self, s: str) -> int:
        seen_chars = set()
        partitions = 0

        for char in s:
            if char in seen_chars:
                seen_chars.clear()
                partitions += 1
            seen_chars.add(char)
        return partitions + 1

# Example usage:
solution = Solution()
s = "abacaba"
result = solution.partitionString(s)
print("Minimum number of partitions:", result)  # Output: Minimum number of partitions: 4
  # Output: Minimum number of partitions: 4
# Out:
# None
# Minimum number of partitions: 1

# %%
class Solution:
    def kthFactor(self, n: int, k: int) -> int:
        f = []
        for i in range(1, n+1):
            if n%i == 0:
                f.append(i)

        if k <= len(f):
            return f[k-1]

        else:
            return

# %%
class Solution:
    def kthFactor(self, n: int, k: int) -> int:
        factors = []
        for i in range(1, n + 1):
            if n % i == 0:
                factors.append(i)

        if k <= len(factors):
            return factors[k - 1]
        else:
            return -1

# %%
from typing import List

class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        if not prices or len(prices) < 2:
            return 0

        max_profit = 0 
        min_price = prices[0]

        for p in prices[1:]:
            if p < min_price:
                min_price = price
                
            else:
                max_profit = max(max_profit, price - min_price)

        return max_profit

# %%
from typing import List

class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        if not prices or len(prices) < 2:
            return 0

        max_profit = 0
        min_price = prices[0]

        for price in prices[1:]:
            if price < min_price:
                min_price = price
            else:
                max_profit = max(max_profit, price - min_price)

        return max_profit
